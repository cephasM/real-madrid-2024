# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service

service = Service("msedgedriver.exe")  # Chemin vers EdgeDriver
options = webdriver.EdgeOptions()

driver = webdriver.Edge(service=service, options=options)
driver.get("https://fbref.com/en/squads/53a2f082/Real-Madrid-Stats")

print("Edge fonctionne avec Selenium !")
driver.quit()
# Out:
# Edge fonctionne avec Selenium !

# %%
from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.edge.options import Options
from bs4 import BeautifulSoup, Comment
import pandas as pd
import time

# Configuration Edge
edge_options = Options()
edge_options.add_argument("--headless")  # Exécution en arrière-plan
edge_options.add_argument("--disable-gpu")
edge_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36 Edg/91.0.864.59")

# Initialisation du WebDriver Edge
service = Service("msedgedriver.exe")  # Assurez-vous que le fichier est dans le dossier
driver = webdriver.Edge(service=service, options=edge_options)

# URL cible
url = "https://fbref.com/en/squads/53a2f082/2023-2024/Real-Madrid-Stats"

try:
    print("🔄 Chargement de la page...")
    driver.get(url)
    time.sleep(5)  # Attente pour le chargement JS

    # Récupération du HTML
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # Détection des tableaux (visibles + commentaires)
    tables = []
    
    # 1. Tableaux visibles
    visible_tables = soup.find_all('table')
    tables.extend(visible_tables)
    
    # 2. Tableaux dans les commentaires HTML
    comments = soup.find_all(string=lambda text: isinstance(text, Comment))
    for comment in comments:
        if '<table' in comment:
            comment_soup = BeautifulSoup(comment, 'html.parser')
            tables.extend(comment_soup.find_all('table'))

    # Filtrage des tableaux valides
    valid_tables = []
    for table in tables:
        if table.has_attr('id'):
            valid_tables.append(table)
            print(f"📋 Tableau détecté : {table['id']}")

    if not valid_tables:
        print("❌ Aucun tableau valide trouvé")
        exit()

    # Extraction des données
    data = {}
    for table in valid_tables:
        try:
            df = pd.read_html(str(table))[0]
            
            # Nettoyage des colonnes multi-niveaux
            if isinstance(df.columns, pd.MultiIndex):
                df.columns = ['_'.join(col).strip() for col in df.columns.values]
            
            data[table['id']] = df
            print(f"✅ {table['id']} extrait avec succès")
        except Exception as e:
            print(f"⚠️ Erreur sur {table['id']} : {str(e)}")

    # Sauvegarde Excel
    if data:
        with pd.ExcelWriter("real_madrid_stats.xlsx") as writer:
            for table_id, df in data.items():
                df.to_excel(writer, sheet_name=table_id[:31])  # Excel limite à 31 caractères
        print("\n💾 Fichier Excel généré : real_madrid_stats.xlsx")

        # Analyse rapide
        if 'stats_standard' in data:
            df = data['stats_standard']
            print("\n🔍 Top 5 Buteurs:")
            print(df[['Player', 'Gls', 'Ast']].sort_values('Gls', ascending=False).head(5))

finally:
    driver.quit()
    print("🚪 Navigateur fermé")
# Out:
# 🔄 Chargement de la page...
# 📋 Tableau détecté : stats_standard_12
# 📋 Tableau détecté : matchlogs_for
# 📋 Tableau détecté : stats_keeper_12
# 📋 Tableau détecté : stats_keeper_adv_12
# 📋 Tableau détecté : stats_shooting_12
# 📋 Tableau détecté : stats_passing_12
# 📋 Tableau détecté : stats_passing_types_12
# 📋 Tableau détecté : stats_gca_12
# 📋 Tableau détecté : stats_defense_12
# 📋 Tableau détecté : stats_possession_12
# 📋 Tableau détecté : stats_playing_time_12
# 📋 Tableau détecté : stats_misc_12
# 📋 Tableau détecté : results2023-2024121_overall
# 📋 Tableau détecté : results2023-2024121_home_away
# ✅ stats_standard_12 extrait avec succès
# ✅ matchlogs_for extrait avec succès
# ✅ stats_keeper_12 extrait avec succès
# ✅ stats_keeper_adv_12 extrait avec succès
# ✅ stats_shooting_12 extrait avec succès
# ✅ stats_passing_12 extrait avec succès
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# ✅ stats_passing_types_12 extrait avec succès
# ✅ stats_gca_12 extrait avec succès
# ✅ stats_defense_12 extrait avec succès
# ✅ stats_possession_12 extrait avec succès
# ✅ stats_playing_time_12 extrait avec succès
# ✅ stats_misc_12 extrait avec succès
# ✅ results2023-2024121_overall extrait avec succès
# ✅ results2023-2024121_home_away extrait avec succès
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\pierr\AppData\Local\Temp\ipykernel_29648\1797056197.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 💾 Fichier Excel généré : real_madrid_stats.xlsx
# 🚪 Navigateur fermé

# %%
# Configuration
input_file = "real_madrid_data/statistiques.xlsx"
output_file = "real_madrid_clean.xlsx"

# 1. Charger toutes les feuilles
print("Chargement des données...")
all_sheets = pd.read_excel(input_file, sheet_name=None)

# 2. Fonction de nettoyage améliorée
def clean_sheet(df):
    # Supprimer les lignes d'en-tête répétées et les lignes vides
    df = df[~df.iloc[:, 0].astype(str).str.contains('Rk|Player|Squad|Opponent', na=False)]
    df = df.dropna(how='all')
    
    # Nettoyer les noms de colonnes multi-niveaux
    if isinstance(df.columns, pd.MultiIndex):
        df.columns = [f"{col[0]}_{col[1]}".strip('_') if col[1] else col[0] 
                     for col in df.columns.values]
    
    # Supprimer les colonnes entièrement vides
    df = df.dropna(axis=1, how='all')
    
    # Standardiser le nom du joueur et filtrer les lignes vides
    player_col = next((col for col in df.columns if 'Player' in str(col)), None)
    if player_col:
        df = df[df[player_col].notna()]
        df[player_col] = df[player_col].astype(str).str.strip()
        df = df.rename(columns={player_col: 'Player'})
    
    # Convertir les colonnes numériques de manière sécurisée
    for col in df.columns:
        if col not in ['Player', 'Nation', 'Pos', 'Age', 'Matches']:
            try:
                df[col] = pd.to_numeric(df[col])
            except:
                # Si la conversion échoue, on garde la valeur originale
                pass
    
    return df

# 3. Nettoyer chaque feuille
print("🧹 Nettoyage des feuilles...")
clean_data = {}
for sheet_name, df in all_sheets.items():
    try:
        print(f"  - Nettoyage de {sheet_name}...")
        clean_data[sheet_name] = clean_sheet(df)
    except Exception as e:
        print(f"Erreur sur {sheet_name}: {str(e)}")

# 4. Créer une table de référence des joueurs
print("👥 Création de la table des joueurs...")
players = pd.DataFrame()

# Essayer de trouver les colonnes Player, Pos, Age dans différentes feuilles
for sheet_name in ['stats_standard_12', 'stats_playing_time_12', 'stats_misc_12']:
    if sheet_name in clean_data:
        df = clean_data[sheet_name]
        cols = {}
        for col in ['Player', 'Pos', 'Age']:
            matching_cols = [c for c in df.columns if col in str(c)]
            if matching_cols:
                cols[col] = matching_cols[0]
        
        if len(cols) == 3:  # On a trouvé les trois colonnes
            players = df[list(cols.values())].rename(columns=cols)
            players = players.drop_duplicates()
            break

if players.empty:
    # Fallback si on n'a pas trouvé les colonnes standard
    print("Impossible de trouver les colonnes standard, création alternative...")
    for sheet_name, df in clean_data.items():
        if 'Player' in df.columns:
            player_cols = {'Player': 'Player'}
            if 'Pos' in df.columns:
                player_cols['Pos'] = 'Pos'
            if 'Age' in df.columns:
                player_cols['Age'] = 'Age'
            
            temp_df = df[list(player_cols.keys())].rename(columns=player_cols)
            players = pd.concat([players, temp_df])
    
    players = players.drop_duplicates()

# 5. Sauvegarde pour Power BI
print("Sauvegarde pour Power BI...")
with pd.ExcelWriter(output_file) as writer:
    # Sauvegarder chaque feuille nettoyée
    for sheet_name, df in clean_data.items():
        df.to_excel(writer, sheet_name=sheet_name[:31], index=False)
    
    # Ajouter la table des joueurs si elle n'est pas vide
    if not players.empty:
        players.to_excel(writer, sheet_name='Players', index=False)
    
    # Créer une feuille résumé si possible
    try:
        summary_data = []
        for sheet_name, df in clean_data.items():
            if 'Player' in df.columns:
                summary_data.append(df.set_index('Player'))
        
        if summary_data:
            summary_df = pd.concat(summary_data, axis=1)
            # Supprimer les colonnes dupliquées (comme Pos, Age qui peuvent apparaître dans plusieurs feuilles)
            summary_df = summary_df.loc[:, ~summary_df.columns.duplicated()]
            summary_df.reset_index(inplace=True)
            summary_df.to_excel(writer, sheet_name='Summary', index=False)
    except Exception as e:
        print(f"Impossible de créer le résumé: {str(e)}")

print(f"""
✅ Nettoyage terminé !
Fichier sauvegardé : {output_file}

Conseils pour Power BI :
1. Importer le fichier Excel
2. Créer des relations entre les tables via la colonne 'Player'
3. Commencer par analyser les indicateurs clés :
   - Buts (Gls), passes décisives (Ast)
   - Tirs (Sh), tirs cadrés (SoT)
   - Actions défensives (Tkl, Int)
   - Performances des gardiens (Saves, CS)
""")
# Out:
# 📂 Chargement des données...
# 🧹 Nettoyage des feuilles...
#   - Nettoyage de stats_standard_12...
#   - Nettoyage de stats_keeper_12...
#   - Nettoyage de stats_keeper_adv_12...
#   - Nettoyage de stats_shooting_12...
#   - Nettoyage de stats_passing_12...
#   - Nettoyage de stats_passing_types_12...
#   - Nettoyage de stats_gca_12...
#   - Nettoyage de stats_defense_12...
#   - Nettoyage de stats_possession_12...
#   - Nettoyage de stats_playing_time_12...
#   - Nettoyage de stats_misc_12...
# 👥 Création de la table des joueurs...
# 💾 Sauvegarde pour Power BI...
# ⚠️ Impossible de créer le résumé: Reindexing only valid with uniquely valued Index objects
#
# ✅ Nettoyage terminé !
# Fichier sauvegardé : real_madrid_clean.xlsx
#
# Conseils pour Power BI :
# 1. Importer le fichier Excel
# 2. Créer des relations entre les tables via la colonne 'Player'
# 3. Commencer par analyser les indicateurs clés :
#    - Buts (Gls), passes décisives (Ast)
#    - Tirs (Sh), tirs cadrés (SoT)
#    - Actions défensives (Tkl, Int)
#    - Performances des gardiens (Saves, CS)

# %%
# Charger le fichier et afficher les noms des feuilles
xlsx_file = 'real_madrid_clean.xlsx'  # Assure-toi du bon chemin
sheets = pd.ExcelFile(xlsx_file).sheet_names
print(sheets)
# Out:
# ['stats_standard_12', 'stats_keeper_12', 'stats_keeper_adv_12', 'stats_shooting_12', 'stats_passing_12', 'stats_passing_types_12', 'stats_gca_12', 'stats_defense_12', 'stats_possession_12', 'stats_playing_time_12', 'stats_misc_12', 'Players']

# %%
def transform_excel_data(file_path):
    # Lire le fichier Excel
    xls = pd.ExcelFile(file_path)
    
    # Créer un dictionnaire pour stocker les DataFrames transformés
    transformed_sheets = {}
    
    # Parcourir chaque feuille
    for sheet_name in xls.sheet_names:
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        
        # Parcourir chaque colonne
        for col in df.columns:
            # Vérifier si la colonne contient des nombres avec des points ou virgules
            if df[col].dtype == 'object':
                try:
                    # Essayer de convertir en float (remplace les virgules par des points)
                    temp_series = df[col].astype(str).str.replace(',', '.').astype(float)
                    
                    # Vérifier si les valeurs converties sont des entiers
                    if all(temp_series.dropna().apply(lambda x: x.is_integer())):
                        # Convertir en int si ce sont des entiers
                        df[col] = temp_series.astype('Int64')  # Int64 permet les NaN
                    else:
                        # Garder en float sinon
                        df[col] = temp_series
                except (ValueError, AttributeError):
                    # Si la conversion échoue, garder la colonne comme object
                    pass
        
        # Stocker le DataFrame transformé
        transformed_sheets[sheet_name] = df
    
    # Écrire les données transformées dans un nouveau fichier Excel
    output_path = file_path.replace('.xlsx', '_transformed.xlsx')
    with pd.ExcelWriter(output_path) as writer:
        for sheet_name, df in transformed_sheets.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    
    return output_path

# Utilisation avec votre fichier
file_path = 'real_madrid_clean.xlsx'
try:
    transformed_file = transform_excel_data(file_path)
    print(f"Transformation réussie ! Fichier enregistré sous : {transformed_file}")
except FileNotFoundError:
    print("Erreur : Le fichier 'real_madrid_clean.xlsx' n'a pas été trouvé dans le dossier du projet.")
except Exception as e:
    print(f"Une erreur s'est produite : {str(e)}")
# Out:
# Transformation réussie ! Fichier enregistré sous : real_madrid_clean_transformed.xlsx

# %%
def analyze_column_formats(file_path):
    # Lire le fichier Excel
    xls = pd.ExcelFile(file_path)
    
    print(f"\nAnalyse des formats de colonnes pour le fichier: {file_path}\n")
    print("="*60)
    
    # Parcourir chaque feuille
    for sheet_name in xls.sheet_names:
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        
        print(f"\nFeuille: {sheet_name}")
        print("-"*40)
        
        # Analyser chaque colonne
        for col in df.columns:
            col_type = df[col].dtype
            sample_value = df[col].iloc[0] if len(df[col]) > 0 else None
            
            # Détection plus précise du format
            if col_type == 'object':
                try:
                    # Test de conversion en float
                    temp = pd.to_numeric(df[col].astype(str).str.replace(',', '.'), errors='raise')
                    if all(temp.dropna().apply(lambda x: x.is_integer())):
                        detected_type = "int (détecté dans texte)"
                    else:
                        detected_type = "float (détecté dans texte)"
                except:
                    if df[col].astype(str).str.match(r'^\d{2}/\d{2}/\d{4}$').any():
                        detected_type = "date (détecté dans texte)"
                    else:
                        detected_type = "texte"
            else:
                if pd.api.types.is_integer_dtype(col_type):
                    detected_type = "int"
                elif pd.api.types.is_float_dtype(col_type):
                    detected_type = "float"
                elif pd.api.types.is_datetime64_any_dtype(col_type):
                    detected_type = "datetime"
                else:
                    detected_type = str(col_type)
            
            # Afficher les informations
            print(f"Colonne: {col:20} | Type pandas: {str(col_type):10} | Format détecté: {detected_type:20} | Exemple: {str(sample_value)}")

# Utilisation avec votre fichier
file_path = 'real_madrid_clean.xlsx'
try:
    analyze_column_formats(file_path)
except FileNotFoundError:
    print(f"Erreur: Le fichier {file_path} n'a pas été trouvé dans le dossier courant.")
except Exception as e:
    print(f"Une erreur s'est produite: {str(e)}")
# Out:
# Analyse des formats de colonnes pour le fichier: real_madrid_clean.xlsx
#
# ============================================================
#
# Feuille: stats_standard_12
# ----------------------------------------
# Colonne: joueur               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: pays                 | Type pandas: object     | Format détecté: texte                | Exemple: uy URU
# Colonne: position             | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: age                  | Type pandas: int64      | Format détecté: int                  | Exemple: 25
# Colonne: MP                   | Type pandas: int64      | Format détecté: int                  | Exemple: 37
# Colonne: match_debute         | Type pandas: int64      | Format détecté: int                  | Exemple: 33
# Colonne: nombre_de_minute_joue | Type pandas: float64    | Format détecté: float                | Exemple: 2904.0
# Colonne: temps_joue_90s       | Type pandas: float64    | Format détecté: float                | Exemple: 32.3
# Colonne: performance_but      | Type pandas: float64    | Format détecté: float                | Exemple: 2.0
# Colonne: Performance_Ast      | Type pandas: float64    | Format détecté: float                | Exemple: 7.0
# Colonne: Performance_G+A      | Type pandas: float64    | Format détecté: float                | Exemple: 9.0
# Colonne: Performance_G-PK     | Type pandas: float64    | Format détecté: float                | Exemple: 2.0
# Colonne: Performance_PK       | Type pandas: float64    | Format détecté: float                | Exemple: 0.0
# Colonne: Performance_PKatt    | Type pandas: float64    | Format détecté: float                | Exemple: 0.0
# Colonne: Performance_CrdY     | Type pandas: float64    | Format détecté: float                | Exemple: 2.0
# Colonne: Performance_CrdR     | Type pandas: float64    | Format détecté: float                | Exemple: 0.0
# Colonne: xG                   | Type pandas: float64    | Format détecté: float                | Exemple: 3.5
# Colonne: npxG                 | Type pandas: float64    | Format détecté: float                | Exemple: 3.5
# Colonne: xAG                  | Type pandas: float64    | Format détecté: float                | Exemple: 5.8
# Colonne: npxG+xAG             | Type pandas: float64    | Format détecté: float                | Exemple: 9.3
# Colonne: PrgC                 | Type pandas: float64    | Format détecté: float                | Exemple: 104.0
# Colonne: PrgP                 | Type pandas: float64    | Format détecté: float                | Exemple: 231.0
# Colonne: PrgR                 | Type pandas: float64    | Format détecté: float                | Exemple: 102.0
# Colonne: pourcentage_but      | Type pandas: float64    | Format détecté: float                | Exemple: 0.06
# Colonne: Ast                  | Type pandas: float64    | Format détecté: float                | Exemple: 0.22
# Colonne: G+A                  | Type pandas: float64    | Format détecté: float                | Exemple: 0.28
# Colonne: G-PK                 | Type pandas: float64    | Format détecté: float                | Exemple: 0.06
# Colonne: G+A-PK               | Type pandas: float64    | Format détecté: float                | Exemple: 0.28
# Colonne: xG2                  | Type pandas: float64    | Format détecté: float                | Exemple: 0.11
# Colonne: xAG3                 | Type pandas: float64    | Format détecté: float                | Exemple: 0.18
# Colonne: xG+xAG               | Type pandas: float64    | Format détecté: float                | Exemple: 0.29
# Colonne: npxG4                | Type pandas: float64    | Format détecté: float                | Exemple: 0.11
# Colonne: npxG+xAG5            | Type pandas: float64    | Format détecté: float                | Exemple: 0.29
# Colonne: Matches              | Type pandas: object     | Format détecté: texte                | Exemple: Matches
# Colonne: Colonne6             | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne7             | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne8             | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne9             | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne10            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne11            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne12            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne13            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne14            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne15            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne16            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne17            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne18            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne19            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne20            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne21            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne22            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne23            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne24            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne25            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne26            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne27            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne28            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne29            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne30            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne31            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne32            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne33            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne34            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne35            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne36            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne37            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne38            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne39            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne40            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne41            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne42            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne43            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne44            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne45            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne46            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne47            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne48            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne49            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne50            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne51            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne52            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne53            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne54            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne55            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne56            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne57            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne58            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne59            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne60            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne61            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne62            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne63            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne64            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne65            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne66            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne67            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne68            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne69            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne70            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne71            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne72            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne73            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne74            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne75            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne76            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne77            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne78            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne79            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne80            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne81            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne82            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne83            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne84            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne85            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne86            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne87            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne88            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne89            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne90            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne91            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne92            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne93            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne94            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne95            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne96            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne97            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne98            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne99            | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne100           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne101           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne102           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne103           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne104           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne105           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne106           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne107           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne108           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne109           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne110           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne111           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne112           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne113           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne114           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne115           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne116           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne117           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne118           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne119           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne120           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne121           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne122           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne123           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne124           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne125           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne126           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne127           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne128           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne129           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne130           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne131           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne132           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne133           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne134           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne135           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne136           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne137           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne138           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne139           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne140           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne141           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne142           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne143           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne144           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne145           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne146           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne147           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne148           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne149           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne150           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne151           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne152           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne153           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne154           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne155           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne156           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne157           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne158           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne159           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne160           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne161           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne162           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne163           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne164           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne165           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne166           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne167           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne168           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne169           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne170           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne171           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne172           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne173           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne174           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne175           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne176           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne177           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne178           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne179           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne180           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne181           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne182           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne183           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne184           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne185           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne186           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne187           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne188           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne189           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne190           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne191           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne192           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne193           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne194           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne195           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne196           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne197           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne198           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne199           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne200           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne201           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne202           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne203           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne204           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne205           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne206           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne207           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne208           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne209           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne210           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne211           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne212           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne213           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne214           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne215           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne216           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne217           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne218           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne219           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne220           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne221           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne222           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne223           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne224           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne225           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne226           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne227           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne228           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne229           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne230           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne231           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne232           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne233           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne234           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne235           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne236           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne237           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne238           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne239           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne240           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne241           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne242           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne243           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne244           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne245           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne246           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne247           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne248           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne249           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne250           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne251           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne252           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne253           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne254           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne255           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne256           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne257           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne258           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne259           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne260           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne261           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne262           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne263           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne264           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne265           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne266           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne267           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne268           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne269           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne270           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne271           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne272           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne273           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne274           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne275           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne276           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne277           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne278           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne279           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne280           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne281           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne282           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne283           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne284           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne285           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne286           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne287           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne288           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne289           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne290           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne291           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne292           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne293           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne294           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne295           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne296           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne297           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne298           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne299           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne300           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne301           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne302           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne303           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne304           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne305           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne306           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne307           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne308           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne309           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne310           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne311           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne312           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne313           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne314           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne315           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne316           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne317           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne318           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne319           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne320           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne321           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne322           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne323           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne324           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne325           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne326           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne327           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne328           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne329           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne330           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne331           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne332           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne333           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne334           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne335           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne336           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne337           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne338           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne339           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne340           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne341           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne342           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne343           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne344           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne345           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne346           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne347           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne348           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne349           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne350           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne351           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne352           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne353           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne354           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne355           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne356           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne357           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne358           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne359           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne360           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne361           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne362           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne363           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne364           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne365           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne366           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne367           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne368           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne369           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne370           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne371           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne372           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne373           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne374           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne375           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne376           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne377           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne378           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne379           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne380           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne381           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne382           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne383           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne384           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne385           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne386           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne387           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne388           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne389           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne390           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne391           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne392           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne393           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne394           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne395           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne396           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne397           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne398           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne399           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne400           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne401           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne402           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne403           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne404           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# Colonne: Colonne405           | Type pandas: float64    | Format détecté: float                | Exemple: nan
# ...
# Colonne: Pass Types_Sw        | Type pandas: int64      | Format détecté: int                  | Exemple: 33
# Colonne: Pass Types_Crs       | Type pandas: int64      | Format détecté: int                  | Exemple: 30
# Colonne: Pass Types_TI        | Type pandas: int64      | Format détecté: int                  | Exemple: 5
# Colonne: Pass Types_CK        | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Corner Kicks_In      | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Corner Kicks_Out     | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Corner Kicks_Str     | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Outcomes_Cmp         | Type pandas: int64      | Format détecté: int                  | Exemple: 1901
# Colonne: Outcomes_Off         | Type pandas: int64      | Format détecté: int                  | Exemple: 9
# Colonne: Outcomes_Blocks      | Type pandas: int64      | Format détecté: int                  | Exemple: 18
# Colonne: Unnamed: 20_level_0_Matches | Type pandas: object     | Format détecté: texte                | Exemple: Matches
#
# Feuille: stats_gca_12
# ----------------------------------------
# Colonne: Unnamed: 0           | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Player               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: Unnamed: 1_level_0_Nation | Type pandas: object     | Format détecté: texte                | Exemple: uy URU
# Colonne: Unnamed: 2_level_0_Pos | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: Unnamed: 3_level_0_Age | Type pandas: float64    | Format détecté: float                | Exemple: 25.0
# Colonne: Unnamed: 4_level_0_90s | Type pandas: float64    | Format détecté: float                | Exemple: 32.3
# Colonne: SCA_SCA              | Type pandas: int64      | Format détecté: int                  | Exemple: 119
# Colonne: SCA_SCA90            | Type pandas: float64    | Format détecté: float                | Exemple: 3.69
# Colonne: SCA Types_PassLive   | Type pandas: int64      | Format détecté: int                  | Exemple: 110
# Colonne: SCA Types_PassDead   | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: SCA Types_TO         | Type pandas: int64      | Format détecté: int                  | Exemple: 3
# Colonne: SCA Types_Sh         | Type pandas: int64      | Format détecté: int                  | Exemple: 3
# Colonne: SCA Types_Fld        | Type pandas: int64      | Format détecté: int                  | Exemple: 1
# Colonne: SCA Types_Def        | Type pandas: int64      | Format détecté: int                  | Exemple: 2
# Colonne: GCA_GCA              | Type pandas: int64      | Format détecté: int                  | Exemple: 14
# Colonne: GCA_GCA90            | Type pandas: float64    | Format détecté: float                | Exemple: 0.43
# Colonne: GCA Types_PassLive   | Type pandas: int64      | Format détecté: int                  | Exemple: 12
# Colonne: GCA Types_PassDead   | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: GCA Types_TO         | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: GCA Types_Sh         | Type pandas: int64      | Format détecté: int                  | Exemple: 2
# Colonne: GCA Types_Fld        | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: GCA Types_Def        | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Unnamed: 21_level_0_Matches | Type pandas: object     | Format détecté: texte                | Exemple: Matches
#
# Feuille: stats_defense_12
# ----------------------------------------
# Colonne: Unnamed: 0           | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Player               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: Unnamed: 1_level_0_Nation | Type pandas: object     | Format détecté: texte                | Exemple: uy URU
# Colonne: Unnamed: 2_level_0_Pos | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: Unnamed: 3_level_0_Age | Type pandas: float64    | Format détecté: float                | Exemple: 25.0
# Colonne: Unnamed: 4_level_0_90s | Type pandas: float64    | Format détecté: float                | Exemple: 32.3
# Colonne: Tackles_Tkl          | Type pandas: int64      | Format détecté: int                  | Exemple: 47
# Colonne: Tackles_TklW         | Type pandas: int64      | Format détecté: int                  | Exemple: 34
# Colonne: Tackles_Def 3rd      | Type pandas: int64      | Format détecté: int                  | Exemple: 22
# Colonne: Tackles_Mid 3rd      | Type pandas: int64      | Format détecté: int                  | Exemple: 13
# Colonne: Tackles_Att 3rd      | Type pandas: int64      | Format détecté: int                  | Exemple: 12
# Colonne: Challenges_Tkl       | Type pandas: int64      | Format détecté: int                  | Exemple: 24
# Colonne: Challenges_Att       | Type pandas: int64      | Format détecté: int                  | Exemple: 42
# Colonne: Challenges_Tkl%      | Type pandas: float64    | Format détecté: float                | Exemple: 57.1
# Colonne: Challenges_Lost      | Type pandas: int64      | Format détecté: int                  | Exemple: 18
# Colonne: Blocks_Blocks        | Type pandas: int64      | Format détecté: int                  | Exemple: 39
# Colonne: Blocks_Sh            | Type pandas: int64      | Format détecté: int                  | Exemple: 2
# Colonne: Blocks_Pass          | Type pandas: int64      | Format détecté: int                  | Exemple: 37
# Colonne: Unnamed: 17_level_0_Int | Type pandas: int64      | Format détecté: int                  | Exemple: 43
# Colonne: Unnamed: 18_level_0_Tkl+Int | Type pandas: int64      | Format détecté: int                  | Exemple: 90
# Colonne: Unnamed: 19_level_0_Clr | Type pandas: int64      | Format détecté: int                  | Exemple: 40
# Colonne: Unnamed: 20_level_0_Err | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Unnamed: 21_level_0_Matches | Type pandas: object     | Format détecté: texte                | Exemple: Matches
#
# Feuille: stats_possession_12
# ----------------------------------------
# Colonne: Unnamed: 0           | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Player               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: Unnamed: 1_level_0_Nation | Type pandas: object     | Format détecté: texte                | Exemple: uy URU
# Colonne: Unnamed: 2_level_0_Pos | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: Unnamed: 3_level_0_Age | Type pandas: float64    | Format détecté: float                | Exemple: 25.0
# Colonne: Unnamed: 4_level_0_90s | Type pandas: float64    | Format détecté: float                | Exemple: 32.3
# Colonne: Touches_Touches      | Type pandas: int64      | Format détecté: int                  | Exemple: 2448
# Colonne: Touches_Def Pen      | Type pandas: int64      | Format détecté: int                  | Exemple: 77
# Colonne: Touches_Def 3rd      | Type pandas: int64      | Format détecté: int                  | Exemple: 384
# Colonne: Touches_Mid 3rd      | Type pandas: int64      | Format détecté: int                  | Exemple: 1382
# Colonne: Touches_Att 3rd      | Type pandas: int64      | Format détecté: int                  | Exemple: 708
# Colonne: Touches_Att Pen      | Type pandas: int64      | Format détecté: int                  | Exemple: 69
# Colonne: Touches_Live         | Type pandas: int64      | Format détecté: int                  | Exemple: 2448
# Colonne: Take-Ons_Att         | Type pandas: int64      | Format détecté: int                  | Exemple: 44
# Colonne: Take-Ons_Succ        | Type pandas: int64      | Format détecté: int                  | Exemple: 22
# Colonne: Take-Ons_Succ%       | Type pandas: float64    | Format détecté: float                | Exemple: 50.0
# Colonne: Take-Ons_Tkld        | Type pandas: int64      | Format détecté: int                  | Exemple: 21
# Colonne: Take-Ons_Tkld%       | Type pandas: float64    | Format détecté: float                | Exemple: 47.7
# Colonne: Carries_Carries      | Type pandas: int64      | Format détecté: int                  | Exemple: 1610
# Colonne: Carries_TotDist      | Type pandas: int64      | Format détecté: int                  | Exemple: 9227
# Colonne: Carries_PrgDist      | Type pandas: int64      | Format détecté: int                  | Exemple: 5027
# Colonne: Carries_PrgC         | Type pandas: int64      | Format détecté: int                  | Exemple: 104
# Colonne: Carries_1/3          | Type pandas: int64      | Format détecté: int                  | Exemple: 102
# Colonne: Carries_CPA          | Type pandas: int64      | Format détecté: int                  | Exemple: 15
# Colonne: Carries_Mis          | Type pandas: int64      | Format détecté: int                  | Exemple: 28
# Colonne: Carries_Dis          | Type pandas: int64      | Format détecté: int                  | Exemple: 12
# Colonne: Receiving_Rec        | Type pandas: int64      | Format détecté: int                  | Exemple: 1925
# Colonne: Receiving_PrgR       | Type pandas: int64      | Format détecté: int                  | Exemple: 102
# Colonne: Unnamed: 27_level_0_Matches | Type pandas: object     | Format détecté: texte                | Exemple: Matches
#
# Feuille: stats_playing_time_12
# ----------------------------------------
# Colonne: Unnamed: 0           | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Player               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: Unnamed: 1_level_0_Nation | Type pandas: object     | Format détecté: texte                | Exemple: uy URU
# Colonne: Unnamed: 2_level_0_Pos | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: Unnamed: 3_level_0_Age | Type pandas: object     | Format détecté: texte                | Exemple: 25
# Colonne: Unnamed: 4_level_0_MP | Type pandas: object     | Format détecté: texte                | Exemple: 37
# Colonne: Playing Time_Min     | Type pandas: object     | Format détecté: texte                | Exemple: 2904
# Colonne: Playing Time_Mn/MP   | Type pandas: object     | Format détecté: texte                | Exemple: 78
# Colonne: Playing Time_Min%    | Type pandas: object     | Format détecté: texte                | Exemple: 84.9
# Colonne: Playing Time_90s     | Type pandas: object     | Format détecté: texte                | Exemple: 32.3
# Colonne: Starts_Starts        | Type pandas: object     | Format détecté: texte                | Exemple: 33
# Colonne: Starts_Mn/Start      | Type pandas: object     | Format détecté: texte                | Exemple: 86
# Colonne: Starts_Compl         | Type pandas: object     | Format détecté: texte                | Exemple: 22
# Colonne: Subs_Subs            | Type pandas: object     | Format détecté: texte                | Exemple: 4
# Colonne: Subs_Mn/Sub          | Type pandas: object     | Format détecté: texte                | Exemple: 19
# Colonne: Subs_unSub           | Type pandas: object     | Format détecté: texte                | Exemple: 1
# Colonne: Team Success_PPM     | Type pandas: object     | Format détecté: texte                | Exemple: 2.49
# Colonne: Team Success_onG     | Type pandas: object     | Format détecté: texte                | Exemple: 76
# Colonne: Team Success_onGA    | Type pandas: object     | Format détecté: texte                | Exemple: 22
# Colonne: Team Success_+/-     | Type pandas: object     | Format détecté: texte                | Exemple: +54
# Colonne: Team Success_+/-90   | Type pandas: object     | Format détecté: texte                | Exemple: +1.67
# Colonne: Team Success_On-Off  | Type pandas: object     | Format détecté: texte                | Exemple: +0.45
# Colonne: Team Success (xG)_onxG | Type pandas: object     | Format détecté: texte                | Exemple: 60.1
# Colonne: Team Success (xG)_onxGA | Type pandas: object     | Format détecté: texte                | Exemple: 30.3
# Colonne: Team Success (xG)_xG+/- | Type pandas: object     | Format détecté: texte                | Exemple: +29.8
# Colonne: Team Success (xG)_xG+/-90 | Type pandas: object     | Format détecté: texte                | Exemple: +0.92
# Colonne: Team Success (xG)_On-Off | Type pandas: object     | Format détecté: texte                | Exemple: +0.30
# Colonne: Unnamed: 26_level_0_Matches | Type pandas: object     | Format détecté: texte                | Exemple: Matches
#
# Feuille: stats_misc_12
# ----------------------------------------
# Colonne: Unnamed: 0           | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Player               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: Unnamed: 1_level_0_Nation | Type pandas: object     | Format détecté: texte                | Exemple: uy URU
# Colonne: Unnamed: 2_level_0_Pos | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: Unnamed: 3_level_0_Age | Type pandas: float64    | Format détecté: float                | Exemple: 25.0
# Colonne: Unnamed: 4_level_0_90s | Type pandas: float64    | Format détecté: float                | Exemple: 32.3
# Colonne: Performance_CrdY     | Type pandas: int64      | Format détecté: int                  | Exemple: 2
# Colonne: Performance_CrdR     | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Performance_2CrdY    | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Performance_Fls      | Type pandas: int64      | Format détecté: int                  | Exemple: 19
# Colonne: Performance_Fld      | Type pandas: int64      | Format détecté: int                  | Exemple: 15
# Colonne: Performance_Off      | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Performance_Crs      | Type pandas: int64      | Format détecté: int                  | Exemple: 30
# Colonne: Performance_Int      | Type pandas: int64      | Format détecté: int                  | Exemple: 43
# Colonne: Performance_TklW     | Type pandas: int64      | Format détecté: int                  | Exemple: 34
# Colonne: Performance_PKwon    | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Performance_PKcon    | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Performance_OG       | Type pandas: int64      | Format détecté: int                  | Exemple: 0
# Colonne: Performance_Recov    | Type pandas: int64      | Format détecté: int                  | Exemple: 160
# Colonne: Aerial Duels_Won     | Type pandas: int64      | Format détecté: int                  | Exemple: 21
# Colonne: Aerial Duels_Lost    | Type pandas: int64      | Format détecté: int                  | Exemple: 10
# Colonne: Aerial Duels_Won%    | Type pandas: float64    | Format détecté: float                | Exemple: 67.7
# Colonne: Unnamed: 21_level_0_Matches | Type pandas: object     | Format détecté: texte                | Exemple: Matches
#
# Feuille: Players
# ----------------------------------------
# Colonne: Player               | Type pandas: object     | Format détecté: texte                | Exemple: Federico Valverde
# Colonne: Unnamed: 2_level_0_Pos | Type pandas: object     | Format détecté: texte                | Exemple: MF
# Colonne: Unnamed: 3_level_0_Age | Type pandas: object     | Format détecté: texte                | Exemple: 25

# %%
def remove_empty_columns(file_path):
    # Lire le fichier Excel
    xls = pd.ExcelFile(file_path)
    
    # Créer un dictionnaire pour stocker les DataFrames modifiés
    cleaned_sheets = {}
    
    # Parcourir chaque feuille
    for sheet_name in xls.sheet_names:
        df = pd.read_excel(file_path, sheet_name=sheet_name)
        
        # Supprimer les colonnes où toutes les valeurs sont NaN/None/vides
        before_cols = len(df.columns)
        df.dropna(axis='columns', how='all', inplace=True)
        after_cols = len(df.columns)
        removed_cols = before_cols - after_cols
        
        print(f"Feuille '{sheet_name}': {removed_cols} colonne(s) vide(s) supprimée(s)")
        
        # Stocker le DataFrame modifié
        cleaned_sheets[sheet_name] = df
    
    # Écrire les données nettoyées dans un nouveau fichier Excel
    output_path = file_path.replace('.xlsx', '_no_empty_columns.xlsx')
    with pd.ExcelWriter(output_path) as writer:
        for sheet_name, df in cleaned_sheets.items():
            df.to_excel(writer, sheet_name=sheet_name, index=False)
    
    return output_path

# Utilisation avec votre fichier
file_path = 'real_madrid_clean.xlsx'
try:
    cleaned_file = remove_empty_columns(file_path)
    print(f"\nNettoyage terminé ! Fichier sauvegardé sous : {cleaned_file}")
except FileNotFoundError:
    print(f"Erreur: Le fichier {file_path} n'a pas été trouvé.")
except Exception as e:
    print(f"Une erreur s'est produite : {str(e)}")
# Out:
# Feuille 'stats_standard_12': 16350 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_keeper_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_keeper_adv_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_shooting_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_passing_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_passing_types_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_gca_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_defense_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_possession_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_playing_time_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'stats_misc_12': 0 colonne(s) vide(s) supprimée(s)
# Feuille 'Players': 0 colonne(s) vide(s) supprimée(s)
#
# Nettoyage terminé ! Fichier sauvegardé sous : real_madrid_clean_no_empty_columns.xlsx
